# %%
# 필요 패키지 import
import pprint
import requests

# %% [markdown]
# # 문제4. 상품과 옵션 정보들을 담고 있는 새로운 객체를 만들어 반환하시오.
# - [힌트] 상품 리스트와 옵션 리스트를 금융상품 코드를 기준으로 매칭할 수 있습니다.
# - [힌트] 아래와 같은 순서로 데이터를 출력하며 진행합니다.
# - 1. 응답을 json 형식으로 변환합니다.
# - 2. key 값이 "result" 인 데이터를 변수에 저장합니다.
# - 3. 2번의 결과 중 key 값이 "baseList" 인 데이터를 변수에 저장합니다.
# - 4. 2번의 결과 중 key 값이 "optionList" 인 데이터를 변수에 저장합니다.
# - 5. 3번에서 저장된 변수를 순회하며, 4번에서 저장된 값들에서 금융 상품 코드가
# -     같은 모든 데이터들을 가져와 새로운 딕셔너리로 저장합니다.
# -     저장 시, 명세서에 맞게 출력되도록 저장합니다.
# - 6. 5번에서 만든 딕셔너리를 결과 리스트에 추가합니다.

# %%
def get_deposit_products():
    # 본인의 API KEY 로 수정합니다.
    api_key = "06842c54d0d16598423dd465287e7a43"
    
    url = f'http://finlife.fss.or.kr/finlifeapi/depositProductsSearch.json?auth={api_key}&topFinGrpNo=020000&pageNo=1'
    
    # 요구사항에 맞도록 이곳의 코드를 수정합니다.
    request = requests.get(url).json() # json 형식으로 변환
    key_result = request['result'] # key 값이 result인 데이터를 변수에 저장
    key_result_baseList = key_result['baseList'] # baseList 데이터를 변수에 저장 - 순회
    key_result_optionList = key_result['optionList'] # optionList 데이터를 변수에 저장 - 금융상품코드 일치시

    result = []
    for base in key_result_baseList:
        info =[]
        for option in key_result_optionList:
            if base['fin_prdt_cd'] == option['fin_prdt_cd']:
                option_kr = {'저축 금리' : option['intr_rate'],
                             '저축 기간' : option['save_trm'],
                             '저축금리유형' : option['intr_rate_type_nm'],
                             '최고 우대금리' : option['intr_rate2']}
                info.append(option_kr)

        info_re = {'금리정보' : info,
                   '금융상품명' : base['fin_prdt_nm'],
                   '금융회사명' : base['kor_co_nm']}
        result.append(info_re)
                
                

    # result = 'result'
    
    return result

# %%
# 아래 코드는 수정하지 않습니다.
if __name__ == '__main__':
    # json 형태의 데이터 반환
    result = get_deposit_products()
    # prrint.prrint(): json 을 보기 좋은 형식으로 출력
    pprint.pprint(result)
# Out:
# [{'금리정보': [{'저축 금리': 3.67, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.67},
#            {'저축 금리': 3.73, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.73},
#            {'저축 금리': 3.36, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.36},
#            {'저축 금리': 3.33, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 3.33}],
#   '금융상품명': 'WON플러스예금',
#   '금융회사명': '우리은행'},
#  {'금리정보': [{'저축 금리': 3.7, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.9},
#            {'저축 금리': 3.9, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 4.2}],
#   '금융상품명': 'e-그린세이브예금',
#   '금융회사명': '한국스탠다드차타드은행'},
#  {'금리정보': [{'저축 금리': 2.46, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.11},
#            {'저축 금리': 3.2, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.85},
#            {'저축 금리': 3.22, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.87},
#            {'저축 금리': 3.24, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 3.89}],
#   '금융상품명': 'DGB주거래우대예금(첫만남고객형)',
#   '금융회사명': '대구은행'},
#  {'금리정보': [{'저축 금리': 2.42, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 2.87},
#            {'저축 금리': 3.16, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.61},
#            {'저축 금리': 3.18, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.63},
#            {'저축 금리': 3.2, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 3.65}],
#   '금융상품명': 'DGB행복파트너예금(일반형)',
#   '금융회사명': '대구은행'},
#  {'금리정보': [{'저축 금리': 3.3, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.75}],
#   '금융상품명': 'DGB함께예금',
#   '금융회사명': '대구은행'},
#  {'금리정보': [{'저축 금리': 2.8, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.05},
#            {'저축 금리': 3.5, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.75},
#            {'저축 금리': 3.2, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.45},
#            {'저축 금리': 3.2, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 3.45}],
#   '금융상품명': 'IM스마트예금',
#   '금융회사명': '대구은행'},
#  {'금리정보': [{'저축 금리': 3.21, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.61}],
#   '금융상품명': '안녕,독도야예금',
#   '금융회사명': '대구은행'},
#  {'금리정보': [{'저축 금리': 2.55, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.5},
#            {'저축 금리': 2.75, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.65},
#            {'저축 금리': 2.8, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 2.8},
#            {'저축 금리': 2.85, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 2.85}],
#   '금융상품명': 'LIVE정기예금',
#   '금융회사명': '부산은행'},
#  {'금리정보': [{'저축 금리': 3.45, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.85},
#            {'저축 금리': 3.6, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 4},
#            {'저축 금리': 3.25, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.65},
#            {'저축 금리': 2.95, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 3.35}],
#   '금융상품명': '더(The) 특판 정기예금',
#   '금융회사명': '부산은행'},
#  {'금리정보': [{'저축 금리': 3.49, '저축 기간': '12', '저축금리유형': '복리', '최고 우대금리': 3.69},
#            {'저축 금리': 3.6, '저축 기간': '24', '저축금리유형': '복리', '최고 우대금리': 3.8},
#            {'저축 금리': 3.74, '저축 기간': '36', '저축금리유형': '복리', '최고 우대금리': 3.94}],
#   '금융상품명': '미즈월복리정기예금',
#   '금융회사명': '광주은행'},
#  {'금리정보': [{'저축 금리': 3.35, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.45},
#            {'저축 금리': 3.39, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.59},
#            {'저축 금리': 3.5, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.7},
#            {'저축 금리': 3.64, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 3.84}],
#   '금융상품명': '스마트모아Dream정기예금',
#   '금융회사명': '광주은행'},
#  {'금리정보': [{'저축 금리': 3.2, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.7},
#            {'저축 금리': 3.3, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.8},
#            {'저축 금리': 3.1, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.1},
#            {'저축 금리': 3, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 3}],
#   '금융상품명': '행운박스예금',
#   '금융회사명': '광주은행'},
#  {'금리정보': [{'저축 금리': 3.29, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.79}],
#   '금융상품명': '굿스타트예금',
#   '금융회사명': '광주은행'},
#  {'금리정보': [{'저축 금리': 3.3, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.55}],
#   '금융상품명': 'KIA타이거즈우승기원예금',
#   '금융회사명': '광주은행'},
#  {'금리정보': [{'저축 금리': 2.85, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 2.95},
#            {'저축 금리': 3.05, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.15},
#            {'저축 금리': 3.15, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.25},
#            {'저축 금리': 3.25, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 3.35}],
#   '금융상품명': '제주Dream\n정기예금\n(개인/만기\n지급식)',
#   '금융회사명': '제주은행'},
#  {'금리정보': [{'저축 금리': 3, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.5},
#            {'저축 금리': 3.1, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.6},
#            {'저축 금리': 3, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.5},
#            {'저축 금리': 3, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 3.5}],
#   '금융상품명': 'J정기예금\n(만기지급식)',
#   '금융회사명': '제주은행'},
#  {'금리정보': [{'저축 금리': 3.75, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.75},
#            {'저축 금리': 3.8, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.8}],
#   '금융상품명': 'JB 다이렉트예금통장\n(만기일시지급식)',
#   '금융회사명': '전북은행'},
#  {'금리정보': [{'저축 금리': 3.8, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.9},
#            {'저축 금리': None, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 4},
#            {'저축 금리': None, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 4.1}],
#   '금융상품명': 'JB 123 정기예금\n (만기일시지급식)',
#   '금융회사명': '전북은행'},
#  {'금리정보': [{'저축 금리': 2.7, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.2},
#            {'저축 금리': 3.05, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.55},
#            {'저축 금리': 3.05, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.55}],
#   '금융상품명': 'BNK더조은정기예금',
#   '금융회사명': '경남은행'},
#  {'금리정보': [{'저축 금리': 3.15, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.45},
#            {'저축 금리': 3.5, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.8},
#            {'저축 금리': 3.55, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.85}],
#   '금융상품명': 'BNK주거래우대정기예금',
#   '금융회사명': '경남은행'},
#  {'금리정보': [{'저축 금리': 3.45, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.65},
#            {'저축 금리': 3.5, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.7},
#            {'저축 금리': 3.6, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 3.8}],
#   '금융상품명': 'IBK평생한가족통장(실세금리정기예금)',
#   '금융회사명': '중소기업은행'},
#  {'금리정보': [{'저축 금리': 3.1, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.4},
#            {'저축 금리': 3.25, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.55}],
#   '금융상품명': 'i-ONE놀이터예금',
#   '금융회사명': '중소기업은행'},
#  {'금리정보': [{'저축 금리': 3.51, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.51},
#            {'저축 금리': 3.57, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.57},
#            {'저축 금리': 3.67, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.67},
#            {'저축 금리': 3.75, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 3.75}],
#   '금융상품명': '1석7조통장(정기예금)',
#   '금융회사명': '중소기업은행'},
#  {'금리정보': [{'저축 금리': 2.7, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 2.7},
#            {'저축 금리': 2.7, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 2.7},
#            {'저축 금리': 2.7, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 2.7},
#            {'저축 금리': 2.7, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 2.7}],
#   '금융상품명': '정기예금',
#   '금융회사명': '한국산업은행'},
#  {'금리정보': [{'저축 금리': 3.3, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.3},
#            {'저축 금리': 3.5, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.5},
#            {'저축 금리': 3.3, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.3},
#            {'저축 금리': 3.3, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 3.3}],
#   '금융상품명': 'KDB 정기예금',
#   '금융회사명': '한국산업은행'},
#  {'금리정보': [{'저축 금리': 0.95, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.68},
#            {'저축 금리': 0.95, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.71},
#            {'저축 금리': 1.05, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.11},
#            {'저축 금리': 1.15, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 3.12}],
#   '금융상품명': 'KB Star 정기예금',
#   '금융회사명': '국민은행'},
#  {'금리정보': [{'저축 금리': 2.75, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.65},
#            {'저축 금리': 2.9, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.7},
#            {'저축 금리': 2.95, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.45},
#            {'저축 금리': 3, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 3.45}],
#   '금융상품명': '쏠편한 정기예금',
#   '금융회사명': '신한은행'},
#  {'금리정보': [{'저축 금리': 3.4, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.5},
#            {'저축 금리': 3.45, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.55}],
#   '금융상품명': 'NH왈츠회전예금 II',
#   '금융회사명': '농협은행주식회사'},
#  {'금리정보': [{'저축 금리': 3.1, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.5},
#            {'저축 금리': 3.15, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.55},
#            {'저축 금리': 3.4, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 3.8}],
#   '금융상품명': 'NH내가Green초록세상예금',
#   '금융회사명': '농협은행주식회사'},
#  {'금리정보': [{'저축 금리': 3.5, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.5},
#            {'저축 금리': 3.55, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.85},
#            {'저축 금리': 3.3, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.3},
#            {'저축 금리': 3.4, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 3.4}],
#   '금융상품명': 'NH올원e예금',
#   '금융회사명': '농협은행주식회사'},
#  {'금리정보': [{'저축 금리': 3.1, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.8}],
#   '금융상품명': 'NH고향사랑기부예금',
#   '금융회사명': '농협은행주식회사'},
#  {'금리정보': [{'저축 금리': 2.3, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.65},
#            {'저축 금리': 2.6, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.7},
#            {'저축 금리': 2.7, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.25},
#            {'저축 금리': 2.8, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 3.25}],
#   '금융상품명': '하나의정기예금',
#   '금융회사명': '하나은행'},
#  {'금리정보': [{'저축 금리': 3.4, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.4},
#            {'저축 금리': 3.8, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.8},
#            {'저축 금리': 3.4, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.4},
#            {'저축 금리': 3.4, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 3.4}],
#   '금융상품명': '코드K 정기예금',
#   '금융회사명': '주식회사 케이뱅크'},
#  {'금리정보': [{'저축 금리': 3, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.4}],
#   '금융상품명': 'Sh평생주거래우대예금\n(만기일시지급식)',
#   '금융회사명': '수협은행'},
#  {'금리정보': [{'저축 금리': 2.95, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.3},
#            {'저축 금리': 3.25, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.6}],
#   '금융상품명': 'Sh해양플라스틱Zero!예금\n(만기일시지급식)',
#   '금융회사명': '수협은행'},
#  {'금리정보': [{'저축 금리': 3.8, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.8},
#            {'저축 금리': 4, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 4}],
#   '금융상품명': '헤이(Hey)정기예금',
#   '금융회사명': '수협은행'},
#  {'금리정보': [{'저축 금리': 2.97, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 4.02}],
#   '금융상품명': 'Sh첫만남우대예금',
#   '금융회사명': '수협은행'},
#  {'금리정보': [{'저축 금리': 3.2, '저축 기간': '6', '저축금리유형': '단리', '최고 우대금리': 3.2},
#            {'저축 금리': 3.5, '저축 기간': '12', '저축금리유형': '단리', '최고 우대금리': 3.5},
#            {'저축 금리': 3.5, '저축 기간': '24', '저축금리유형': '단리', '최고 우대금리': 3.5},
#            {'저축 금리': 3.5, '저축 기간': '36', '저축금리유형': '단리', '최고 우대금리': 3.5}],
#   '금융상품명': '카카오뱅크 정기예금',
#   '금융회사명': '주식회사 카카오뱅크'}]
