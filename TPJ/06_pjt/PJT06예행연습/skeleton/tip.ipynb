# %% [markdown]
# ###
# - auth_user => auth는 기본 앱, user는 모델 명
#
# - user를 변경해줘 라는 명령이 들어오면 -> DB를 날리고 다시 만들어야함.
#
# - 엔티티(무엇을 만들까?)와 스키마 는 설계 / 테이블은 구현
#   - 예를들어 회원을 만들때 유저네임이랑 패스워드를 얻어야함 이중 회원을 만들다가 엔티티. 어떻게 만들까?에 대한 내용 즉 유저네임은 문자열이며 몇글자 이런식의 조건을 넣는것을 스키마. 테이블은 스키마를 토대로 생성한것.
#
# - django = 세션
#   - 로그인
#   1. 세션 데이터 생성
#   2. DB에 저장
#   3. 세션 ID를 쿠키에 저장
